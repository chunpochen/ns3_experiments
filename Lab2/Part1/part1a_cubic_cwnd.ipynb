# %%
import os
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt

print("Current Working Directory", os.getcwd())
# Out:
# Current Working Directory /home/leo/workspace/bake/source/ns-3.39/examples/Lab/Lab2/Part1

# %%
data = pd.read_csv('/home/leo/workspace/bake/source/ns-3.39/TcpVariantsComparison-cwnd.data', sep=' ', names=['Time', 'Cwnd'])

plt.figure(figsize=(10, 6))
plt.plot(data['Time'], data['Cwnd'])
plt.title('TCP Congestion Window')
plt.xlabel('Time (seconds)')
plt.ylabel('Congestion Window Size (bytes)')
plt.grid(True)
plt.show()
